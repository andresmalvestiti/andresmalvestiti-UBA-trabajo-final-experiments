# %%
# Para que funciones, todos nuestros scripts debemos exportar las siguientes variables de entorno
# %env AWS_ACCESS_KEY_ID=minio   
# %env AWS_SECRET_ACCESS_KEY=minio123 
# %env MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# %env AWS_ENDPOINT_URL_S3=http://localhost:9000
# Out:
# env: AWS_ACCESS_KEY_ID=minio
# env: AWS_SECRET_ACCESS_KEY=minio123
# env: MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# env: AWS_ENDPOINT_URL_S3=http://localhost:9000

# %%
# !echo $AWS_ACCESS_KEY_ID
# !echo $AWS_SECRET_ACCESS_KEY
# !echo $MLFLOW_S3_ENDPOINT_URL
# Out:
# $AWS_ACCESS_KEY_ID
# $AWS_SECRET_ACCESS_KEY
# $MLFLOW_S3_ENDPOINT_URL

# %%
import awswrangler as wr

# Cargamos los datos para realizar nuestro estudio.
X_train =  wr.s3.read_csv("s3://data/final/train/X_train_scaled.csv")
y_train =  wr.s3.read_csv("s3://data/final/train/y_train.csv")

X_val =  wr.s3.read_csv("s3://data/final/val/X_val_scaled.csv")
y_val =  wr.s3.read_csv("s3://data/final/val/y_val.csv")

X_test =  wr.s3.read_csv("s3://data/final/test/X_test_scaled.csv")
y_test =  wr.s3.read_csv("s3://data/final/test/y_test.csv")

# %%
import pandas as pd
import optuna
import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import KFold
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import StandardScaler

# Set the MLflow tracking URI
mlflow.set_tracking_uri('http://localhost:5000')

# Set up the MLflow experiment
mlflow.set_experiment("classification_neural_network_experiment_2")

class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(NeuralNetwork, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(hidden_size, hidden_size // 2),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(hidden_size // 2, 1),  # Single output for binary classification
            nn.Sigmoid()  # Sigmoid for binary classification
        )
        
    def forward(self, x):
        return self.layers(x)

def objective(trial):
    # Hyperparameters to optimize
    hidden_size = trial.suggest_int('hidden_size', 32, 256)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_int('batch_size', 16, 128)
    epochs = trial.suggest_int('epochs', 10, 50)
    
    # Combine training and validation sets
    X_combined = pd.concat([X_train, X_val])
    y_combined = pd.concat([y_train, y_val])
    
    # Convert to PyTorch tensors
    X_tensor = torch.FloatTensor(X_combined.values)
    y_tensor = torch.FloatTensor(y_combined.values).reshape(-1, 1)  # Reshape to match network output
    
    # K-fold cross validation setup
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    cv_scores = []
    cv_f1_scores = []
    
    with mlflow.start_run(run_name="neural_network_cv_run"):
        # Log parameters
        mlflow.log_params({
            'hidden_size': hidden_size,
            'learning_rate': learning_rate,
            'batch_size': batch_size,
            'epochs': epochs
        })
        
        # Perform cross-validation
        for fold, (train_idx, val_idx) in enumerate(kf.split(X_tensor)):
            # Split data for this fold
            X_fold_train = X_tensor[train_idx]
            y_fold_train = y_tensor[train_idx]
            X_fold_val = X_tensor[val_idx]
            y_fold_val = y_tensor[val_idx]
            
            # Create data loaders
            train_dataset = TensorDataset(X_fold_train, y_fold_train)
            train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
            
            # Initialize model and optimizer
            model = NeuralNetwork(X_tensor.shape[1], hidden_size)
            optimizer = optim.Adam(model.parameters(), lr=learning_rate)
            criterion = nn.BCELoss()  # Binary Cross Entropy Loss
            
            # Training loop
            model.train()
            for epoch in range(epochs):
                for batch_X, batch_y in train_loader:
                    optimizer.zero_grad()
                    outputs = model(batch_X)
                    loss = criterion(outputs, batch_y)
                    loss.backward()
                    optimizer.step()
            
            # Evaluation
            model.eval()
            with torch.no_grad():
                val_outputs = model(X_fold_val)
                predicted = (val_outputs >= 0.5).float()  # Threshold at 0.5 for binary prediction
                
                fold_accuracy = accuracy_score(y_fold_val, predicted)
                fold_f1 = f1_score(y_fold_val, predicted, average='weighted')
                
                cv_scores.append(fold_accuracy)
                cv_f1_scores.append(fold_f1)
                
                # Log metrics for this fold
                mlflow.log_metric(f"fold_{fold}_accuracy", fold_accuracy)
                mlflow.log_metric(f"fold_{fold}_f1", fold_f1)
        
        # Calculate and log mean metrics
        mean_cv_accuracy = np.mean(cv_scores)
        std_cv_accuracy = np.std(cv_scores)
        mean_cv_f1 = np.mean(cv_f1_scores)
        std_cv_f1 = np.std(cv_f1_scores)
        
        mlflow.log_metric("mean_cv_accuracy", mean_cv_accuracy)
        mlflow.log_metric("std_cv_accuracy", std_cv_accuracy)
        mlflow.log_metric("mean_cv_f1", mean_cv_f1)
        mlflow.log_metric("std_cv_f1", std_cv_f1)
        
        return mean_cv_f1

# Run the optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Print results
print(f"Best parameters: {study.best_trial.params}")
print(f"Best F1 score: {study.best_trial.value}")
# Out:
# 2025/02/02 00:21:57 INFO mlflow.tracking.fluent: Experiment with name 'classification_neural_network_experiment_2' does not exist. Creating a new experiment.
# [I 2025-02-02 00:21:57,469] A new study created in memory with name: no-name-3f3c7f94-35d9-4462-992d-a61fedc831e0
# 2025/02/02 00:22:09 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/183bd992ae3f4d02b654b39b365e6dcd.
# 2025/02/02 00:22:09 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:22:09,588] Trial 0 finished with value: 0.9479326291343082 and parameters: {'hidden_size': 80, 'learning_rate': 0.00046744353116018924, 'batch_size': 48, 'epochs': 21}. Best is trial 0 with value: 0.9479326291343082.
# 2025/02/02 00:22:20 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/3b597bedc05c4588a45d9b87ddabce2d.
# 2025/02/02 00:22:20 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:22:20,731] Trial 1 finished with value: 0.9548702364160613 and parameters: {'hidden_size': 75, 'learning_rate': 0.008865695142709516, 'batch_size': 108, 'epochs': 45}. Best is trial 1 with value: 0.9548702364160613.
# 2025/02/02 00:22:30 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/a3debd55358144d0b93c67b9a86f6743.
# 2025/02/02 00:22:30 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:22:30,044] Trial 2 finished with value: 0.9440444737818148 and parameters: {'hidden_size': 112, 'learning_rate': 0.00016530610081378881, 'batch_size': 93, 'epochs': 36}. Best is trial 1 with value: 0.9548702364160613.
# 2025/02/02 00:22:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/6449dd5e12ce4184a9bbd1320d807863.
# 2025/02/02 00:22:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:22:49,504] Trial 3 finished with value: 0.9555182283345551 and parameters: {'hidden_size': 39, 'learning_rate': 0.006957587609233575, 'batch_size': 35, 'epochs': 43}. Best is trial 3 with value: 0.9555182283345551.
# 2025/02/02 00:22:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/7d9ffe4bb7a04297a72a8bf724ecfb82.
# 2025/02/02 00:22:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:22:55,939] Trial 4 finished with value: 0.9522084705259438 and parameters: {'hidden_size': 184, 'learning_rate': 0.0012143907764370946, 'batch_size': 32, 'epochs': 10}. Best is trial 3 with value: 0.9555182283345551.
# 2025/02/02 00:23:07 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/5fcb429b88f7488aa7f265fec93068ee.
# 2025/02/02 00:23:07 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:23:07,638] Trial 5 finished with value: 0.9537967376344234 and parameters: {'hidden_size': 172, 'learning_rate': 0.003634246202089783, 'batch_size': 83, 'epochs': 38}. Best is trial 3 with value: 0.9555182283345551.
# 2025/02/02 00:23:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/f3a6d01d24954e13a477a88ec47e0981.
# 2025/02/02 00:23:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:23:14,023] Trial 6 finished with value: 0.9440444737818148 and parameters: {'hidden_size': 73, 'learning_rate': 0.00037089648513975764, 'batch_size': 83, 'epochs': 22}. Best is trial 3 with value: 0.9555182283345551.
# 2025/02/02 00:23:28 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/e3bf132406cd4603ad3753d0f6a921ef.
# 2025/02/02 00:23:28 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:23:28,746] Trial 7 finished with value: 0.9552453679473396 and parameters: {'hidden_size': 99, 'learning_rate': 0.0037191033965209026, 'batch_size': 49, 'epochs': 31}. Best is trial 3 with value: 0.9555182283345551.
# 2025/02/02 00:23:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/c2c1d7104de94dbdbf3d19963a5b5dd6.
# 2025/02/02 00:23:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:23:36,270] Trial 8 finished with value: 0.9433173194514479 and parameters: {'hidden_size': 117, 'learning_rate': 0.00029865675039744005, 'batch_size': 114, 'epochs': 39}. Best is trial 3 with value: 0.9555182283345551.
# 2025/02/02 00:23:50 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/930f1aa5857049cf823625cb61b10623.
# 2025/02/02 00:23:50 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:23:50,175] Trial 9 finished with value: 0.9575970055728223 and parameters: {'hidden_size': 172, 'learning_rate': 0.001134665470303155, 'batch_size': 26, 'epochs': 25}. Best is trial 9 with value: 0.9575970055728223.
# 2025/02/02 00:24:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/6cdfe42db6b14de093e5c019cf303375.
# 2025/02/02 00:24:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:24:08,711] Trial 10 finished with value: 0.9548130676848118 and parameters: {'hidden_size': 253, 'learning_rate': 0.0010693985719908853, 'batch_size': 18, 'epochs': 20}. Best is trial 9 with value: 0.9575970055728223.
# 2025/02/02 00:24:27 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/da0a9a362c404760beff8d929e65a9f6.
# 2025/02/02 00:24:27 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:24:27,213] Trial 11 finished with value: 0.9528801498867713 and parameters: {'hidden_size': 213, 'learning_rate': 0.0027306196946568152, 'batch_size': 55, 'epochs': 47}. Best is trial 9 with value: 0.9575970055728223.
# 2025/02/02 00:24:41 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/aaa1dbdae7fe4ca0b8c6bcc837ab514f.
# 2025/02/02 00:24:41 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:24:41,610] Trial 12 finished with value: 0.9571347835176975 and parameters: {'hidden_size': 34, 'learning_rate': 0.00949716053099586, 'batch_size': 18, 'epochs': 28}. Best is trial 9 with value: 0.9575970055728223.
# 2025/02/02 00:25:00 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/f8295a7f49e3418b8476eb3719653721.
# 2025/02/02 00:25:00 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:25:00,208] Trial 13 finished with value: 0.9549534310054695 and parameters: {'hidden_size': 151, 'learning_rate': 0.001853859077306154, 'batch_size': 24, 'epochs': 29}. Best is trial 9 with value: 0.9575970055728223.
# 2025/02/02 00:25:09 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/81e2e677cdc44485ad7da59abe2215d8.
# 2025/02/02 00:25:09 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:25:09,483] Trial 14 finished with value: 0.9440444737818148 and parameters: {'hidden_size': 211, 'learning_rate': 0.00010125883943894008, 'batch_size': 63, 'epochs': 28}. Best is trial 9 with value: 0.9575970055728223.
# 2025/02/02 00:25:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/3e4d23ea0df04d2da531395fea580043.
# 2025/02/02 00:25:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:25:16,504] Trial 15 finished with value: 0.9517671512055514 and parameters: {'hidden_size': 141, 'learning_rate': 0.005581228923784265, 'batch_size': 37, 'epochs': 13}. Best is trial 9 with value: 0.9575970055728223.
# 2025/02/02 00:25:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/898874c6823e4548a840a7927f7b9180.
# 2025/02/02 00:25:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:25:33,833] Trial 16 finished with value: 0.958504568093522 and parameters: {'hidden_size': 139, 'learning_rate': 0.0006425159542555312, 'batch_size': 22, 'epochs': 25}. Best is trial 16 with value: 0.958504568093522.
# 2025/02/02 00:25:38 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/c5b2dd3616214beb9213d965a03dca19.
# 2025/02/02 00:25:38 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:25:38,481] Trial 17 finished with value: 0.9504056662167422 and parameters: {'hidden_size': 145, 'learning_rate': 0.000695524887758839, 'batch_size': 68, 'epochs': 15}. Best is trial 16 with value: 0.958504568093522.
# 2025/02/02 00:25:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/b37347f95a6f47cf818cbb82744812e0.
# 2025/02/02 00:25:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:25:52,120] Trial 18 finished with value: 0.9582638639420382 and parameters: {'hidden_size': 193, 'learning_rate': 0.0006514592990274559, 'batch_size': 42, 'epochs': 33}. Best is trial 16 with value: 0.958504568093522.
# 2025/02/02 00:26:05 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/4b196fdc891e45d998fe9e7b9a5d595c.
# 2025/02/02 00:26:05 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:26:05,699] Trial 19 finished with value: 0.9563486247569637 and parameters: {'hidden_size': 214, 'learning_rate': 0.0006483426014799074, 'batch_size': 39, 'epochs': 34}. Best is trial 16 with value: 0.958504568093522.
# 2025/02/02 00:26:11 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/ecac86a02a64411db0d64edccfc4086e.
# 2025/02/02 00:26:11 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:26:11,789] Trial 20 finished with value: 0.9453825101634432 and parameters: {'hidden_size': 237, 'learning_rate': 0.00023332547280227446, 'batch_size': 52, 'epochs': 17}. Best is trial 16 with value: 0.958504568093522.
# 2025/02/02 00:26:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/449c7343dd1e4fadbdc4190f4ecb22b7.
# 2025/02/02 00:26:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:26:23,461] Trial 21 finished with value: 0.9528734644441851 and parameters: {'hidden_size': 184, 'learning_rate': 0.0015878363015334308, 'batch_size': 30, 'epochs': 25}. Best is trial 16 with value: 0.958504568093522.
# 2025/02/02 00:26:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/5ad0a7126aa34476b7bc241aa6ea41ba.
# 2025/02/02 00:26:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:26:36,073] Trial 22 finished with value: 0.9586242603341747 and parameters: {'hidden_size': 166, 'learning_rate': 0.0007611464925817927, 'batch_size': 25, 'epochs': 24}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:26:46 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/8758708a5a8e43a4a600d92e48587059.
# 2025/02/02 00:26:46 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:26:46,752] Trial 23 finished with value: 0.957505405938526 and parameters: {'hidden_size': 131, 'learning_rate': 0.0006843210862739374, 'batch_size': 43, 'epochs': 33}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:27:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/0ce0e5f7800c4dc3b97f4b7463318b8e.
# 2025/02/02 00:27:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:27:08,058] Trial 24 finished with value: 0.9574972453012748 and parameters: {'hidden_size': 159, 'learning_rate': 0.0005295348854498569, 'batch_size': 17, 'epochs': 25}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:27:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/77d12c81a62245e8962144dcc078af78.
# 2025/02/02 00:27:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:27:18,241] Trial 25 finished with value: 0.9570164298823176 and parameters: {'hidden_size': 198, 'learning_rate': 0.0008859463666079042, 'batch_size': 28, 'epochs': 18}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:27:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/5a2aee666b2642999957786b753098b5.
# 2025/02/02 00:27:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:27:31,944] Trial 26 finished with value: 0.9580700083295174 and parameters: {'hidden_size': 165, 'learning_rate': 0.0019506634976188962, 'batch_size': 59, 'epochs': 41}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:27:44 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/7c6d9b21f4b8484584c63a45871d262c.
# 2025/02/02 00:27:44 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:27:44,887] Trial 27 finished with value: 0.9554921855954067 and parameters: {'hidden_size': 129, 'learning_rate': 0.00038288570322473264, 'batch_size': 42, 'epochs': 31}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:28:00 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/6fbe62259b694b528e1b22d2d98022f9.
# 2025/02/02 00:28:00 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:28:00,873] Trial 28 finished with value: 0.9575481882081881 and parameters: {'hidden_size': 196, 'learning_rate': 0.00022943734555142624, 'batch_size': 23, 'epochs': 25}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:28:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/20ee9ac7919c444c82e6fbe61192adb0.
# 2025/02/02 00:28:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:28:08,272] Trial 29 finished with value: 0.9547274305052025 and parameters: {'hidden_size': 229, 'learning_rate': 0.0004238881096210394, 'batch_size': 45, 'epochs': 21}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:28:19 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/a5178253bbbd4b35a9aeaad60c0840fc.
# 2025/02/02 00:28:19 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:28:19,784] Trial 30 finished with value: 0.9542015342780209 and parameters: {'hidden_size': 183, 'learning_rate': 0.001466681479207966, 'batch_size': 70, 'epochs': 34}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:28:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/e6cc7a84dfa3495b93db03a8dc14035c.
# 2025/02/02 00:28:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:28:33,148] Trial 31 finished with value: 0.9563238959248486 and parameters: {'hidden_size': 162, 'learning_rate': 0.001994841150894744, 'batch_size': 50, 'epochs': 42}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:28:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/13483457e1a54d0d8f48a0e866d16876.
# 2025/02/02 00:28:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:28:45,622] Trial 32 finished with value: 0.9585377792870198 and parameters: {'hidden_size': 91, 'learning_rate': 0.0009042179199698208, 'batch_size': 60, 'epochs': 48}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:28:56 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/c733866013d14d4cbe5d08d425a7aba6.
# 2025/02/02 00:28:56 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:28:56,369] Trial 33 finished with value: 0.9563058645348169 and parameters: {'hidden_size': 93, 'learning_rate': 0.0008087081963584801, 'batch_size': 80, 'epochs': 47}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:29:06 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/4bc7aefe88f342c4bb5df63b042dd20d.
# 2025/02/02 00:29:06 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:29:06,185] Trial 34 finished with value: 0.9502761513026728 and parameters: {'hidden_size': 66, 'learning_rate': 0.0005334142378673494, 'batch_size': 96, 'epochs': 49}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:29:20 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/a56e18821e0b42d494c01c2a4ced8ff0.
# 2025/02/02 00:29:20 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:29:20,586] Trial 35 finished with value: 0.958124512654905 and parameters: {'hidden_size': 111, 'learning_rate': 0.0009131347065209949, 'batch_size': 35, 'epochs': 37}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:29:26 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/91b7ab43d1464b2c89baf862a35aabc1.
# 2025/02/02 00:29:26 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:29:26,299] Trial 36 finished with value: 0.9450196275534667 and parameters: {'hidden_size': 51, 'learning_rate': 0.0005914765844184445, 'batch_size': 57, 'epochs': 24}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:29:29 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/3990f1666b5e4361b881d19f28ba8395.
# 2025/02/02 00:29:29 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:29:29,800] Trial 37 finished with value: 0.9457440636246067 and parameters: {'hidden_size': 129, 'learning_rate': 0.00045807278625925905, 'batch_size': 125, 'epochs': 22}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:29:47 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/077a931302a14e518c168c36e36857f9.
# 2025/02/02 00:29:47 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:29:47,495] Trial 38 finished with value: 0.951450111260019 and parameters: {'hidden_size': 88, 'learning_rate': 0.0012531958203383326, 'batch_size': 33, 'epochs': 45}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:29:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/87234d694b704c7cb00fd7cb65cfb16a.
# 2025/02/02 00:29:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:29:55,164] Trial 39 finished with value: 0.9450195432375729 and parameters: {'hidden_size': 111, 'learning_rate': 0.0002693146843704669, 'batch_size': 62, 'epochs': 27}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:30:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/ac97d7eef0d2436bb091430fa65d6d61.
# 2025/02/02 00:30:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:30:01,148] Trial 40 finished with value: 0.9472006519148819 and parameters: {'hidden_size': 62, 'learning_rate': 0.0007365806816147747, 'batch_size': 22, 'epochs': 10}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:30:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/07e47f7e8e674624b7972f592a951ad2.
# 2025/02/02 00:30:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:30:16,865] Trial 41 finished with value: 0.957623848539616 and parameters: {'hidden_size': 100, 'learning_rate': 0.0009070214176399155, 'batch_size': 33, 'epochs': 37}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:30:28 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/e992b6d36ec144a9b7f8d25c6f715e43.
# 2025/02/02 00:30:28 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:30:28,306] Trial 42 finished with value: 0.9560505763457605 and parameters: {'hidden_size': 108, 'learning_rate': 0.0009870498817707695, 'batch_size': 37, 'epochs': 32}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:30:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/4dca1fa2db5944c79cc0a911acb06f6c.
# 2025/02/02 00:30:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:30:37,339] Trial 43 finished with value: 0.9492366670994272 and parameters: {'hidden_size': 82, 'learning_rate': 0.000366431288053642, 'batch_size': 77, 'epochs': 40}. Best is trial 22 with value: 0.9586242603341747.
# 2025/02/02 00:30:56 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/4334f4062a014eda90e7be7fb18bdc52.
# 2025/02/02 00:30:56 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:30:56,302] Trial 44 finished with value: 0.962015754586327 and parameters: {'hidden_size': 121, 'learning_rate': 0.0013103557445230478, 'batch_size': 28, 'epochs': 35}. Best is trial 44 with value: 0.962015754586327.
# 2025/02/02 00:31:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/2e784710418d4f6a813c56cc0cb920e8.
# 2025/02/02 00:31:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:31:23,273] Trial 45 finished with value: 0.951312979093513 and parameters: {'hidden_size': 135, 'learning_rate': 0.001390619948937561, 'batch_size': 16, 'epochs': 35}. Best is trial 44 with value: 0.962015754586327.
# 2025/02/02 00:31:38 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/0cf51e9c4f804217818d334266adae2f.
# 2025/02/02 00:31:38 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:31:38,353] Trial 46 finished with value: 0.953619407026372 and parameters: {'hidden_size': 122, 'learning_rate': 0.0024286431515764665, 'batch_size': 29, 'epochs': 30}. Best is trial 44 with value: 0.962015754586327.
# 2025/02/02 00:31:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/aaa43100b5de41829986be101d22e3d5.
# 2025/02/02 00:31:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:31:52,089] Trial 47 finished with value: 0.9569310755526876 and parameters: {'hidden_size': 146, 'learning_rate': 0.0011274065404885533, 'batch_size': 22, 'epochs': 19}. Best is trial 44 with value: 0.962015754586327.
# 2025/02/02 00:32:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/92d33bddb666420c9d2ffe9f976125f3.
# 2025/02/02 00:32:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:32:14,015] Trial 48 finished with value: 0.9552449763801946 and parameters: {'hidden_size': 172, 'learning_rate': 0.0003137697272078065, 'batch_size': 47, 'epochs': 50}. Best is trial 44 with value: 0.962015754586327.
# 2025/02/02 00:32:26 INFO mlflow.tracking._tracking_service.client: 🏃 View run neural_network_cv_run at: http://localhost:5000/#/experiments/18/runs/cb6ca6e79caa4bb4a43c2f6206817833.
# 2025/02/02 00:32:26 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/18.
# [I 2025-02-02 00:32:26,792] Trial 49 finished with value: 0.9540384852850383 and parameters: {'hidden_size': 193, 'learning_rate': 0.0005293171285517647, 'batch_size': 41, 'epochs': 27}. Best is trial 44 with value: 0.962015754586327.
# Best parameters: {'hidden_size': 121, 'learning_rate': 0.0013103557445230478, 'batch_size': 28, 'epochs': 35}
# Best F1 score: 0.962015754586327
