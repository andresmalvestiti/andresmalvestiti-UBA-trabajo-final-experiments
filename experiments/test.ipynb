# %%
# Para que funciones, todos nuestros scripts debemos exportar las siguientes variables de entorno
# %env AWS_ACCESS_KEY_ID=minio   
# %env AWS_SECRET_ACCESS_KEY=minio123 
# %env MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# %env AWS_ENDPOINT_URL_S3=http://localhost:9000
# Out:
# env: AWS_ACCESS_KEY_ID=minio
# env: AWS_SECRET_ACCESS_KEY=minio123
# env: MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# env: AWS_ENDPOINT_URL_S3=http://localhost:9000

# %%
# !echo $AWS_ACCESS_KEY_ID
# !echo $AWS_SECRET_ACCESS_KEY
# !echo $MLFLOW_S3_ENDPOINT_URL
# Out:
# $AWS_ACCESS_KEY_ID
# $AWS_SECRET_ACCESS_KEY
# $MLFLOW_S3_ENDPOINT_URL

# %%
import awswrangler as wr

# Cargamos los datos para realizar nuestro estudio.
X_train =  wr.s3.read_csv("s3://data/final/train/sca_X_train.csv")
y_train =  wr.s3.read_csv("s3://data/final/train/sca_y_train.csv")

X_test =  wr.s3.read_csv("s3://data/final/test/sca_X_test.csv")
y_test =  wr.s3.read_csv("s3://data/final/test/sca_y_test.csv")

# %%
import pandas as pd
import optuna
import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelBinarizer

# Set the MLflow tracking URI
mlflow.set_tracking_uri('http://localhost:5000') 

# Set up the MLflow experiment
mlflow.set_experiment("classification_optimization_2")

# Objective function for Optuna
def objective(trial):
    # Suggest classification model
    classifier_name = trial.suggest_categorical('classifier', ['RandomForest', 'XGBoost', 'SVC'])
    
    # Define hyperparameters for each classifier
    if classifier_name == 'RandomForest':
        n_estimators = trial.suggest_int('n_estimators', 10, 200)
        max_depth = trial.suggest_int('max_depth', 2, 32)
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
        
    elif classifier_name == 'XGBoost':
        eta = trial.suggest_float('eta', 0.01, 0.5)
        max_depth = trial.suggest_int('max_depth', 3, 20)
        model = XGBClassifier(eta=eta, max_depth=max_depth, use_label_encoder=False)
        
    else:
        C = trial.suggest_float('C', 0.1, 10.0)
        model = SVC(C=C, probability=True)  # SVC with probability=True for ROC AUC
    
    # Start an MLflow run
    with mlflow.start_run(run_name=f"{classifier_name}_run"):
        # Log the classifier name
        mlflow.log_param("classifier", classifier_name)
        
        # Log hyperparameters based on the classifier
        if classifier_name == 'RandomForest':
            mlflow.log_param('n_estimators', n_estimators)
            mlflow.log_param('max_depth', max_depth)
        elif classifier_name == 'XGBoost':
            mlflow.log_param('eta', eta)
            mlflow.log_param('max_depth', max_depth)
        else:
            mlflow.log_param('C', C)
        
        # Train the model
        model.fit(X_train, y_train)
        
        # Make predictions
        y_pred = model.predict(X_test)
        y_proba = model.predict_proba(X_test)[:, 1] if classifier_name != 'SVC' or len(set(y_train)) > 2 else None
        
        # Evaluate the metrics
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')
        
        # Log accuracy and F1 score
        mlflow.log_metric("accuracy", accuracy)
        mlflow.log_metric("f1_score", f1)
        
        # ROC AUC is applicable if we have predicted probabilities
        if y_proba is not None:
            try:
                if len(set(y_train)) > 2:
                    lb = LabelBinarizer()
                    y_test_bin = lb.fit_transform(y_test)
                    roc_auc = roc_auc_score(y_test_bin, y_proba, average='weighted', multi_class='ovr')
                else:
                    roc_auc = roc_auc_score(y_test, y_proba)
                mlflow.log_metric("roc_auc", roc_auc)
            except ValueError as e:
                print(f"Error calculating ROC AUC: {e}")
        
        # Log the model
        mlflow.sklearn.log_model(model, classifier_name)
        
        return accuracy

# Run the optimization with Optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Print the best model and parameters
print(f"Best model: {study.best_trial.params}")
# Out:
# 2024/09/17 23:27:41 INFO mlflow.tracking.fluent: Experiment with name 'classification_optimization_2' does not exist. Creating a new experiment.
# [I 2024-09-17 23:27:41,639] A new study created in memory with name: no-name-b0b090a6-dce9-44d1-81f7-0a4431fe995c
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2024/09/17 23:27:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:27:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/3/runs/26a1bcfc452a48f3a6fa17b43103efee.
# 2024/09/17 23:27:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:27:49,589] Trial 0 finished with value: 0.967032967032967 and parameters: {'classifier': 'SVC', 'C': 3.3664476978681055}. Best is trial 0 with value: 0.967032967032967.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 2024/09/17 23:27:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:27:53 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/3/runs/ac4cb0dbb89441e4beac9325653ceae9.
# 2024/09/17 23:27:53 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:27:53,298] Trial 1 finished with value: 0.9697802197802198 and parameters: {'classifier': 'RandomForest', 'n_estimators': 13, 'max_depth': 10}. Best is trial 1 with value: 0.9697802197802198.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:27:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:27:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:27:57 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/4f18da33f16b4819a7792cf6fd4fbdc4.
# 2024/09/17 23:27:57 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:27:57,360] Trial 2 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.312886004420482, 'max_depth': 17}. Best is trial 2 with value: 0.9835164835164835.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 2024/09/17 23:28:00 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/3/runs/8ae66b975d5043d38e14c5cacc974d49.
# 2024/09/17 23:28:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:01,134] Trial 3 finished with value: 0.9752747252747253 and parameters: {'classifier': 'RandomForest', 'n_estimators': 85, 'max_depth': 14}. Best is trial 2 with value: 0.9835164835164835.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:28:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:04 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/bb5ebd79b1054101a306cc4c1c6aa217.
# 2024/09/17 23:28:04 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:04,997] Trial 4 finished with value: 0.9752747252747253 and parameters: {'classifier': 'XGBoost', 'eta': 0.10528630607483071, 'max_depth': 20}. Best is trial 2 with value: 0.9835164835164835.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2024/09/17 23:28:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/3/runs/71ca731c7f8d4b928d0a78c24f7a1365.
# 2024/09/17 23:28:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:08,290] Trial 5 finished with value: 0.967032967032967 and parameters: {'classifier': 'SVC', 'C': 1.4975328745570835}. Best is trial 2 with value: 0.9835164835164835.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2024/09/17 23:28:11 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:11 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/3/runs/7f776e50ebb946e3b53f542f4ba8dd00.
# 2024/09/17 23:28:11 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:11,375] Trial 6 finished with value: 0.9642857142857143 and parameters: {'classifier': 'SVC', 'C': 0.4991945979012291}. Best is trial 2 with value: 0.9835164835164835.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:28:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/982c6f5cd5474f549e0471b5451d9e95.
# 2024/09/17 23:28:15 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:15,274] Trial 7 finished with value: 0.9862637362637363 and parameters: {'classifier': 'XGBoost', 'eta': 0.3859624698807333, 'max_depth': 17}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 2024/09/17 23:28:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/3/runs/8d55e2e5006840e29c6f338c970c8482.
# 2024/09/17 23:28:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:18,842] Trial 8 finished with value: 0.9642857142857143 and parameters: {'classifier': 'RandomForest', 'n_estimators': 18, 'max_depth': 2}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2024/09/17 23:28:22 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/3/runs/dbadce05551c45f5b48e84cd9be76e0a.
# 2024/09/17 23:28:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:22,658] Trial 9 finished with value: 0.967032967032967 and parameters: {'classifier': 'SVC', 'C': 6.588001296620609}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:28:26 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:26 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/4e0e91b78de44c9b95a6f1e6974271a0.
# 2024/09/17 23:28:26 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:26,503] Trial 10 finished with value: 0.9862637362637363 and parameters: {'classifier': 'XGBoost', 'eta': 0.4934716181799724, 'max_depth': 10}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:28:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:30 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/ec7cc387ba35488b867332d71cfcce07.
# 2024/09/17 23:28:30 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:30,482] Trial 11 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.4963440573222702, 'max_depth': 9}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:28:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/f1a83253405f448b8c1ca675d43b6a15.
# 2024/09/17 23:28:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:34,199] Trial 12 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.4833581785751419, 'max_depth': 7}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:28:37 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/080dad2eecc84e95ad1d7ae249d6feeb.
# 2024/09/17 23:28:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:37,802] Trial 13 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.3555789865468998, 'max_depth': 14}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:28:41 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:41 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/037fd54484954993b7efe96e04591969.
# 2024/09/17 23:28:41 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:41,326] Trial 14 finished with value: 0.9725274725274725 and parameters: {'classifier': 'XGBoost', 'eta': 0.40390057191907724, 'max_depth': 13}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:28:44 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:44 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/89d417f57cc04bb68060ce7d054cee81.
# 2024/09/17 23:28:44 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:44,849] Trial 15 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.20747963724037224, 'max_depth': 18}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:28:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/3eaf2df756794ba3b65ebc5c8def1ab8.
# 2024/09/17 23:28:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:48,364] Trial 16 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.4155379285177015, 'max_depth': 6}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:28:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/c85584db0f3f469ea8f49cd8bd8d0db1.
# 2024/09/17 23:28:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:52,049] Trial 17 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.23812365808224062, 'max_depth': 16}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:28:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/573e1a36505e42e080a116c694cdccb3.
# 2024/09/17 23:28:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:55,516] Trial 18 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.42735828370760376, 'max_depth': 11}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 2024/09/17 23:28:58 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:28:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/3/runs/975c4d50d61d4c60818602f0f1cddcf2.
# 2024/09/17 23:28:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:28:59,115] Trial 19 finished with value: 0.9752747252747253 and parameters: {'classifier': 'RandomForest', 'n_estimators': 195, 'max_depth': 26}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:28:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:02 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:02 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/26ad75350ce647869f280711d658d999.
# 2024/09/17 23:29:02 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:02,624] Trial 20 finished with value: 0.978021978021978 and parameters: {'classifier': 'XGBoost', 'eta': 0.30684209996834694, 'max_depth': 7}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:29:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:06 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/4d41eba395ee479d91949e167831b369.
# 2024/09/17 23:29:06 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:06,165] Trial 21 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.2959308014169666, 'max_depth': 19}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:29:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:10 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/4776f62b56104cd0946ba59e3af7fa07.
# 2024/09/17 23:29:10 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:10,090] Trial 22 finished with value: 0.978021978021978 and parameters: {'classifier': 'XGBoost', 'eta': 0.35496383654146546, 'max_depth': 16}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:29:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:14 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/baf2bced25c0402f8b4571d6c4b4bcc7.
# 2024/09/17 23:29:14 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:14,268] Trial 23 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.16133683186614736, 'max_depth': 17}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:29:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/9f16f8e150e442ed990b919889f1f45b.
# 2024/09/17 23:29:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:18,152] Trial 24 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.3437321182578508, 'max_depth': 20}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:29:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:22 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/c478a5d82a634fc3830e269fcadbc6c0.
# 2024/09/17 23:29:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:22,359] Trial 25 finished with value: 0.9862637362637363 and parameters: {'classifier': 'XGBoost', 'eta': 0.4452166500160806, 'max_depth': 12}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:29:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:26 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:26 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/d729e82758444604828941b460f1dd0e.
# 2024/09/17 23:29:26 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:26,590] Trial 26 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.4508516541089215, 'max_depth': 12}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:29:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:30 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/3d738f92ece14452bb56f7fe2c2a87df.
# 2024/09/17 23:29:30 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:30,758] Trial 27 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.39449263978116034, 'max_depth': 9}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2024/09/17 23:29:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/3/runs/71481380d960437eaa962abdc03e8072.
# 2024/09/17 23:29:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:34,774] Trial 28 finished with value: 0.967032967032967 and parameters: {'classifier': 'SVC', 'C': 9.528527059407455}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 2024/09/17 23:29:39 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/3/runs/3381702a45494b25abfe6e43206cdc49.
# 2024/09/17 23:29:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:39,197] Trial 29 finished with value: 0.9752747252747253 and parameters: {'classifier': 'RandomForest', 'n_estimators': 192, 'max_depth': 25}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2024/09/17 23:29:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:43 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/3/runs/095eb3b94c804a959f36df15efdf8d4b.
# 2024/09/17 23:29:43 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:43,072] Trial 30 finished with value: 0.967032967032967 and parameters: {'classifier': 'SVC', 'C': 9.911020146483299}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:29:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:47 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/2c3e43f1c2d7449489322b463f3e78ce.
# 2024/09/17 23:29:47 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:47,082] Trial 31 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.44960860813043185, 'max_depth': 15}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:29:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:51 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/85b97eb6861f48ac81479a13e2f02b9b.
# 2024/09/17 23:29:51 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:51,280] Trial 32 finished with value: 0.9725274725274725 and parameters: {'classifier': 'XGBoost', 'eta': 0.01851671203846389, 'max_depth': 12}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:29:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/b284d5ead08b4b1b852ab267e3718e8e.
# 2024/09/17 23:29:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:55,616] Trial 33 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.48087715577679163, 'max_depth': 17}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:29:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:29:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:29:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/11b7607e91f847e59ab487184480b769.
# 2024/09/17 23:29:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:29:59,924] Trial 34 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.30531661426291773, 'max_depth': 10}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 2024/09/17 23:30:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:04 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/3/runs/0d9547b1d1ff4a6a9bcd0cca0e8cb506.
# 2024/09/17 23:30:04 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:04,397] Trial 35 finished with value: 0.9807692307692307 and parameters: {'classifier': 'RandomForest', 'n_estimators': 119, 'max_depth': 24}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:30:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:09 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/c51bfca974f7435595560844caafd33e.
# 2024/09/17 23:30:09 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:09,097] Trial 36 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.3750323485900746, 'max_depth': 10}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:30:13 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/84529c3687524da1ba71eb9ea147ee6c.
# 2024/09/17 23:30:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:13,372] Trial 37 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.44969374673059187, 'max_depth': 14}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2024/09/17 23:30:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/3/runs/93dc14e1352246e5b197717aee2d0228.
# 2024/09/17 23:30:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:16,890] Trial 38 finished with value: 0.967032967032967 and parameters: {'classifier': 'SVC', 'C': 6.112925546100605}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 2024/09/17 23:30:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:20 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/3/runs/0544f5cbf7b14137acf4cd804e593723.
# 2024/09/17 23:30:20 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:20,596] Trial 39 finished with value: 0.9642857142857143 and parameters: {'classifier': 'RandomForest', 'n_estimators': 123, 'max_depth': 3}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:30:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/53de6c71a289455782cc20d84460caae.
# 2024/09/17 23:30:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:24,604] Trial 40 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.3251458063873625, 'max_depth': 13}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:30:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:28 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/893c62c7d60b4eebabbc9c3447fa0b70.
# 2024/09/17 23:30:28 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:28,767] Trial 41 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.4990826596105601, 'max_depth': 5}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:30:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:32 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/9ed84cb8165745bfba386bfc0fa1a7d4.
# 2024/09/17 23:30:32 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:33,008] Trial 42 finished with value: 0.978021978021978 and parameters: {'classifier': 'XGBoost', 'eta': 0.453283204488106, 'max_depth': 8}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:30:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/b4ae6a110dd3497e86dc0ccfe69f628e.
# 2024/09/17 23:30:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:37,110] Trial 43 finished with value: 0.978021978021978 and parameters: {'classifier': 'XGBoost', 'eta': 0.4780917984963015, 'max_depth': 5}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:30:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/e4808ff3ac874673ba8a8b1317b01193.
# 2024/09/17 23:30:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:40,981] Trial 44 finished with value: 0.9862637362637363 and parameters: {'classifier': 'XGBoost', 'eta': 0.42553705867509306, 'max_depth': 8}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:30:44 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/7e77061fe15143a38b030401c5a1af85.
# 2024/09/17 23:30:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:45,020] Trial 45 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.39281774102856803, 'max_depth': 9}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2024/09/17 23:30:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/3/runs/28934870e1d340e3a2cb13257c9d696b.
# 2024/09/17 23:30:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:48,514] Trial 46 finished with value: 0.967032967032967 and parameters: {'classifier': 'SVC', 'C': 3.6625905881694902}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:30:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/53519ad2feb44ce18ea14f714ff7e039.
# 2024/09/17 23:30:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:52,443] Trial 47 finished with value: 0.978021978021978 and parameters: {'classifier': 'XGBoost', 'eta': 0.4312406881671789, 'max_depth': 11}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:30:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:30:56 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/a47964820b8b4999bc463484f07de31d.
# 2024/09/17 23:30:56 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:30:56,242] Trial 48 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.37654228181291305, 'max_depth': 8}. Best is trial 7 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/17 23:31:00 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/17 23:31:00 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/3/runs/a2c1cb29d4a54c92bb4f79e7fe2f5d74.
# 2024/09/17 23:31:00 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/3.
# [I 2024-09-17 23:31:00,226] Trial 49 finished with value: 0.9862637362637363 and parameters: {'classifier': 'XGBoost', 'eta': 0.2509763290983816, 'max_depth': 15}. Best is trial 7 with value: 0.9862637362637363.
# Best model: {'classifier': 'XGBoost', 'eta': 0.3859624698807333, 'max_depth': 17}
