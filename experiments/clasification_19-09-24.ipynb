# %%
# Para que funciones, todos nuestros scripts debemos exportar las siguientes variables de entorno
# %env AWS_ACCESS_KEY_ID=minio   
# %env AWS_SECRET_ACCESS_KEY=minio123 
# %env MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# %env AWS_ENDPOINT_URL_S3=http://localhost:9000
# Out:
# env: AWS_ACCESS_KEY_ID=minio
# env: AWS_SECRET_ACCESS_KEY=minio123
# env: MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# env: AWS_ENDPOINT_URL_S3=http://localhost:9000

# %%
# !echo $AWS_ACCESS_KEY_ID
# !echo $AWS_SECRET_ACCESS_KEY
# !echo $MLFLOW_S3_ENDPOINT_URL
# Out:
# $AWS_ACCESS_KEY_ID
# $AWS_SECRET_ACCESS_KEY
# $MLFLOW_S3_ENDPOINT_URL

# %%
import awswrangler as wr

# Cargamos los datos para realizar nuestro estudio.
X_train =  wr.s3.read_csv("s3://data/final/train/sca_X_train.csv")
y_train =  wr.s3.read_csv("s3://data/final/train/sca_y_train.csv")

X_test =  wr.s3.read_csv("s3://data/final/test/sca_X_test.csv")
y_test =  wr.s3.read_csv("s3://data/final/test/sca_y_test.csv")

# %%
import pandas as pd
import optuna
import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import numpy as np

# Set the MLflow tracking URI
mlflow.set_tracking_uri('http://localhost:5000') 

# Set up the MLflow experiment
mlflow.set_experiment("classification_optimization_19-09-24")

# Objective function for Optuna
def objective(trial):
    # Sugerimos el modelo de clasificación
    classifier_name = trial.suggest_categorical('classifier', ['RandomForest', 'XGBoost', 'SVC', 'LogisticRegression', 'KNN'])
    
    # Definimos hiperparámetros para cada clasificador
    if classifier_name == 'RandomForest':
        n_estimators = trial.suggest_int('n_estimators', 10, 200)
        max_depth = trial.suggest_int('max_depth', 2, 32)
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
        
    elif classifier_name == 'XGBoost':
        eta = trial.suggest_float('eta', 0.01, 0.5)
        max_depth = trial.suggest_int('max_depth', 3, 20)
        model = XGBClassifier(eta=eta, max_depth=max_depth, use_label_encoder=False)
        
    elif classifier_name == 'SVC':
        C = trial.suggest_float('C', 0.1, 10.0)
        model = SVC(C=C, probability=True)  # SVC con probability=True para ROC AUC
    
    elif classifier_name == 'LogisticRegression':
        C = trial.suggest_float('C', 0.1, 10.0)
        penalty = trial.suggest_categorical('penalty', ['l2'])  # Simplificado a 'l2'
        solver = 'lbfgs'  # Solver por defecto
        model = LogisticRegression(C=C, penalty=penalty, solver=solver, max_iter=1000)
    
    else:  # KNN
        n_neighbors = trial.suggest_int('n_neighbors', 1, 30)
        weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
        p = trial.suggest_int('p', 1, 2)  # p=1 Manhattan, p=2 Euclidiana
        model = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights, p=p)
    
    # Iniciamos una ejecución en MLflow
    with mlflow.start_run(run_name=f"{classifier_name}_run"):
        # Registramos el nombre del clasificador
        mlflow.log_param("classifier", classifier_name)
        
        # Registramos los hiperparámetros según el clasificador
        if classifier_name == 'RandomForest':
            mlflow.log_param('n_estimators', n_estimators)
            mlflow.log_param('max_depth', max_depth)
        elif classifier_name == 'XGBoost':
            mlflow.log_param('eta', eta)
            mlflow.log_param('max_depth', max_depth)
        elif classifier_name == 'SVC':
            mlflow.log_param('C', C)
        elif classifier_name == 'LogisticRegression':
            mlflow.log_param('C', C)
            mlflow.log_param('penalty', penalty)
        else:  # KNN
            mlflow.log_param('n_neighbors', n_neighbors)
            mlflow.log_param('weights', weights)
            mlflow.log_param('p', p)
        
        # Entrenamos el modelo
        model.fit(X_train, y_train.values.ravel())
        
        # Realizamos predicciones
        y_pred = model.predict(X_test)
        
        # Verificamos si el modelo tiene predict_proba
        if hasattr(model, "predict_proba"):
            y_proba = model.predict_proba(X_test)[:, 1]
        else:
            # Para modelos sin predict_proba, usamos decision_function
            if hasattr(model, "decision_function"):
                y_scores = model.decision_function(X_test)
                y_proba = (y_scores - y_scores.min()) / (y_scores.max() - y_scores.min())
            else:
                y_proba = None  # No se puede calcular ROC AUC
        
        # Evaluamos las métricas
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')
        
        # Registramos accuracy y F1 score
        mlflow.log_metric("accuracy", accuracy)
        mlflow.log_metric("f1_score", f1)
        
        # Calculamos y registramos ROC AUC si es aplicable
        if y_proba is not None:
            try:
                if len(set(y_train.values.ravel())) > 2:
                    lb = LabelBinarizer()
                    y_test_bin = lb.fit_transform(y_test)
                    roc_auc = roc_auc_score(y_test_bin, model.predict_proba(X_test), average='weighted', multi_class='ovr')
                else:
                    roc_auc = roc_auc_score(y_test, y_proba)
                
                mlflow.log_metric("roc_auc", roc_auc)
                
                # Calculamos la curva ROC
                fpr, tpr, thresholds = roc_curve(y_test, y_proba)
                roc_auc_value = auc(fpr, tpr)
                
                # Graficamos la curva ROC
                plt.figure()
                plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc_value)
                plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
                plt.xlim([0.0, 1.0])
                plt.ylim([0.0, 1.05])
                plt.xlabel('False Positive Rate')
                plt.ylabel('True Positive Rate')
                plt.title(f'Receiver Operating Characteristic - {classifier_name}')
                plt.legend(loc="lower right")
                # Guardamos la figura temporalmente
                plt.savefig('roc_curve.png')
                plt.close()
                # Registramos la curva ROC
                mlflow.log_artifact('roc_curve.png')
                
            except ValueError as e:
                print(f"Error al calcular ROC AUC: {e}")
        
        # Calculamos la matriz de confusión
        cm = confusion_matrix(y_test, y_pred)
        
        # Graficamos la matriz de confusión
        plt.figure()
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title(f'Matriz de Confusión - {classifier_name}')
        plt.colorbar()
        tick_marks = np.arange(len(np.unique(y_test)))
        plt.xticks(tick_marks, np.unique(y_test), rotation=45)
        plt.yticks(tick_marks, np.unique(y_test))
        plt.tight_layout()
        plt.ylabel('Etiqueta verdadera')
        plt.xlabel('Etiqueta predicha')
        # Guardamos la figura temporalmente
        plt.savefig('confusion_matrix.png')
        plt.close()
        # Registramos la matriz de confusión
        mlflow.log_artifact('confusion_matrix.png')
        
        # Registramos el modelo
        mlflow.sklearn.log_model(model, classifier_name)
        
        return accuracy

# Ejecutamos la optimización con Optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Imprimimos el mejor modelo y sus parámetros
print(f"Mejor modelo: {study.best_trial.params}")
# Out:
# [I 2024-09-19 11:53:44,357] A new study created in memory with name: no-name-24c2dc52-e7e1-4e12-a0ac-2d41895bebb2
# 2024/09/19 11:53:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:53:51 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/4/runs/c34eb4b5684f4fb5bddf53dd93fa1b02.
# 2024/09/19 11:53:51 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:53:52,015] Trial 0 finished with value: 0.9752747252747253 and parameters: {'classifier': 'RandomForest', 'n_estimators': 42, 'max_depth': 19}. Best is trial 0 with value: 0.9752747252747253.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 2024/09/19 11:53:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:53:56 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_run at: http://localhost:5000/#/experiments/4/runs/15de125ac5894936a6c00e9f081d2eb7.
# 2024/09/19 11:53:56 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:53:56,714] Trial 1 finished with value: 0.9697802197802198 and parameters: {'classifier': 'LogisticRegression', 'C': 8.263441451471474, 'penalty': 'l2'}. Best is trial 0 with value: 0.9752747252747253.
# 2024/09/19 11:54:00 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:00 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_run at: http://localhost:5000/#/experiments/4/runs/ca5b0014164d4556b881192a1bf170ea.
# 2024/09/19 11:54:00 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:00,699] Trial 2 finished with value: 0.9642857142857143 and parameters: {'classifier': 'KNN', 'n_neighbors': 8, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9752747252747253.
# 2024/09/19 11:54:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:05 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/4/runs/51936b4ffbfa45ce88905cf85b7167a9.
# 2024/09/19 11:54:05 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:05,407] Trial 3 finished with value: 0.9835164835164835 and parameters: {'classifier': 'RandomForest', 'n_estimators': 27, 'max_depth': 25}. Best is trial 3 with value: 0.9835164835164835.
# 2024/09/19 11:54:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:09 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/4/runs/7b796ad8d3534fe6ac1b50c5c3999a7e.
# 2024/09/19 11:54:09 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:09,530] Trial 4 finished with value: 0.967032967032967 and parameters: {'classifier': 'SVC', 'C': 8.015063871444012}. Best is trial 3 with value: 0.9835164835164835.
# 2024/09/19 11:54:13 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/4/runs/7c72dde0cca4434b9a097c3e2de765e0.
# 2024/09/19 11:54:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:13,236] Trial 5 finished with value: 0.967032967032967 and parameters: {'classifier': 'SVC', 'C': 4.493476533107793}. Best is trial 3 with value: 0.9835164835164835.
# 2024/09/19 11:54:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:17 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/4/runs/29e50d43092c45f8ab1d56e8f13c1148.
# 2024/09/19 11:54:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:17,221] Trial 6 finished with value: 0.9725274725274725 and parameters: {'classifier': 'RandomForest', 'n_estimators': 25, 'max_depth': 19}. Best is trial 3 with value: 0.9835164835164835.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 2024/09/19 11:54:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_run at: http://localhost:5000/#/experiments/4/runs/d5baa5a5af504f1f9285fc226510afd8.
# 2024/09/19 11:54:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:21,726] Trial 7 finished with value: 0.9725274725274725 and parameters: {'classifier': 'LogisticRegression', 'C': 5.931071330046477, 'penalty': 'l2'}. Best is trial 3 with value: 0.9835164835164835.
# 2024/09/19 11:54:25 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:25 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/4/runs/702d0a9b81a74b2a831c724fa4fbf22f.
# 2024/09/19 11:54:25 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:25,885] Trial 8 finished with value: 0.978021978021978 and parameters: {'classifier': 'RandomForest', 'n_estimators': 39, 'max_depth': 26}. Best is trial 3 with value: 0.9835164835164835.
# 2024/09/19 11:54:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:29 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/4/runs/4c9e1a5464c24b68acee4a1f4d10c0de.
# 2024/09/19 11:54:29 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:29,614] Trial 9 finished with value: 0.9642857142857143 and parameters: {'classifier': 'RandomForest', 'n_estimators': 168, 'max_depth': 3}. Best is trial 3 with value: 0.9835164835164835.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:54:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:54:33 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/9e8963d937e84d0c8d05b9f3f441787a.
# 2024/09/19 11:54:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:34,104] Trial 10 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.2848096431408448, 'max_depth': 6}. Best is trial 3 with value: 0.9835164835164835.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:54:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:54:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:38 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/5e51806b4dea404d8e7be46c0a31730f.
# 2024/09/19 11:54:38 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:38,666] Trial 11 finished with value: 0.9862637362637363 and parameters: {'classifier': 'XGBoost', 'eta': 0.2787625890592521, 'max_depth': 5}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:54:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:54:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/a20190f25e1a4a849cac27efa04952d7.
# 2024/09/19 11:54:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:42,976] Trial 12 finished with value: 0.9752747252747253 and parameters: {'classifier': 'XGBoost', 'eta': 0.05616470457336775, 'max_depth': 9}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:54:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:54:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:47 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/f1c082ea0e17445b9ad18e411d66f5a2.
# 2024/09/19 11:54:47 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:47,509] Trial 13 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.47819316561809333, 'max_depth': 13}. Best is trial 11 with value: 0.9862637362637363.
# 2024/09/19 11:54:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:51 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_run at: http://localhost:5000/#/experiments/4/runs/ec8421fe5eb14f878deaa097ebbeef4c.
# 2024/09/19 11:54:51 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:51,644] Trial 14 finished with value: 0.9642857142857143 and parameters: {'classifier': 'KNN', 'n_neighbors': 30, 'weights': 'distance', 'p': 2}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:54:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:54:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/35ea9b8371884c94963daddde34f2d0f.
# 2024/09/19 11:54:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:55,982] Trial 15 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.2522157368610533, 'max_depth': 12}. Best is trial 11 with value: 0.9862637362637363.
# 2024/09/19 11:54:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:54:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/4/runs/82c4c65a4ddf42829694f9ff1e41fbfb.
# 2024/09/19 11:54:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:54:59,946] Trial 16 finished with value: 0.9807692307692307 and parameters: {'classifier': 'RandomForest', 'n_estimators': 110, 'max_depth': 32}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:55:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:55:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:04 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/155ba09c1f434b81a6515af2f774d422.
# 2024/09/19 11:55:04 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:04,276] Trial 17 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.2651411345359287, 'max_depth': 3}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 2024/09/19 11:55:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_run at: http://localhost:5000/#/experiments/4/runs/1f77c43de0b646e49c1c5d36da4ed562.
# 2024/09/19 11:55:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:08,497] Trial 18 finished with value: 0.9752747252747253 and parameters: {'classifier': 'LogisticRegression', 'C': 0.3805507549021492, 'penalty': 'l2'}. Best is trial 11 with value: 0.9862637362637363.
# 2024/09/19 11:55:12 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:12 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/4/runs/9e2332cfa35c4873b4a94630f0d45527.
# 2024/09/19 11:55:12 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:12,407] Trial 19 finished with value: 0.9642857142857143 and parameters: {'classifier': 'SVC', 'C': 0.2534995767071928}. Best is trial 11 with value: 0.9862637362637363.
# 2024/09/19 11:55:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_run at: http://localhost:5000/#/experiments/4/runs/bfd36508ac1d48cab8b29259b1bf8b82.
# 2024/09/19 11:55:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:16,606] Trial 20 finished with value: 0.9642857142857143 and parameters: {'classifier': 'KNN', 'n_neighbors': 23, 'weights': 'distance', 'p': 1}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:55:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:55:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/859558aa667248fd8f308971fc8bd3bd.
# 2024/09/19 11:55:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:21,056] Trial 21 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.2558851833764827, 'max_depth': 7}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:55:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:55:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:25 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/9be5298a75524460b1cea8a2653ae01d.
# 2024/09/19 11:55:25 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:25,113] Trial 22 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.3574912528273873, 'max_depth': 6}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:55:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:55:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:29 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/0f220b5adc2a43e9ab3e74586d7d4e83.
# 2024/09/19 11:55:29 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:29,069] Trial 23 finished with value: 0.978021978021978 and parameters: {'classifier': 'XGBoost', 'eta': 0.10150742582511726, 'max_depth': 6}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:55:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:55:33 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/c3d1a6f46b7143c2919de8ba7a1ac5fb.
# 2024/09/19 11:55:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:33,545] Trial 24 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.3644028711793184, 'max_depth': 9}. Best is trial 11 with value: 0.9862637362637363.
# 2024/09/19 11:55:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:38 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/4/runs/8cc29444f1354b3fa53ad4a94bbb8024.
# 2024/09/19 11:55:38 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:38,218] Trial 25 finished with value: 0.978021978021978 and parameters: {'classifier': 'RandomForest', 'n_estimators': 96, 'max_depth': 24}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:55:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:55:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/94048a92a4c24600900ebf5cf737edec.
# 2024/09/19 11:55:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:42,942] Trial 26 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.17619083206828834, 'max_depth': 5}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:55:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:55:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:47 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/d72498216d4a4bfcae10356f7edba7cd.
# 2024/09/19 11:55:47 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:47,614] Trial 27 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.3633751466336039, 'max_depth': 9}. Best is trial 11 with value: 0.9862637362637363.
# 2024/09/19 11:55:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/4/runs/458bbdb25dbf4ee2aba8a0065180cf53.
# 2024/09/19 11:55:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:52,462] Trial 28 finished with value: 0.9807692307692307 and parameters: {'classifier': 'RandomForest', 'n_estimators': 89, 'max_depth': 24}. Best is trial 11 with value: 0.9862637362637363.
# 2024/09/19 11:55:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:55:57 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/4/runs/f2d822a236884d2388f55603c7e18808.
# 2024/09/19 11:55:57 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:55:57,137] Trial 29 finished with value: 0.978021978021978 and parameters: {'classifier': 'RandomForest', 'n_estimators': 181, 'max_depth': 16}. Best is trial 11 with value: 0.9862637362637363.
# 2024/09/19 11:56:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/4/runs/d2a489bb762e4a79a18e875279c65f19.
# 2024/09/19 11:56:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:01,253] Trial 30 finished with value: 0.967032967032967 and parameters: {'classifier': 'SVC', 'C': 4.109472823842817}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:56:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:56:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:05 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/9822f8cd3b344ceebf1b5c36ab920629.
# 2024/09/19 11:56:05 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:05,695] Trial 31 finished with value: 0.9862637362637363 and parameters: {'classifier': 'XGBoost', 'eta': 0.2088141016060122, 'max_depth': 12}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:56:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:56:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:09 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/c4365d4968284505b51f55c61a664b94.
# 2024/09/19 11:56:09 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:09,891] Trial 32 finished with value: 0.978021978021978 and parameters: {'classifier': 'XGBoost', 'eta': 0.18422529758620082, 'max_depth': 4}. Best is trial 11 with value: 0.9862637362637363.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:56:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:56:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:14 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/93d1347842c24068b3790616c89d00f3.
# 2024/09/19 11:56:14 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:14,570] Trial 33 finished with value: 0.989010989010989 and parameters: {'classifier': 'XGBoost', 'eta': 0.3003621812007603, 'max_depth': 8}. Best is trial 33 with value: 0.989010989010989.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 2024/09/19 11:56:19 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:19 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_run at: http://localhost:5000/#/experiments/4/runs/876888e426d44de39e6680a3402bcd42.
# 2024/09/19 11:56:19 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:19,282] Trial 34 finished with value: 0.9752747252747253 and parameters: {'classifier': 'LogisticRegression', 'C': 2.4582267727633718, 'penalty': 'l2'}. Best is trial 33 with value: 0.989010989010989.
# 2024/09/19 11:56:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_run at: http://localhost:5000/#/experiments/4/runs/e4cc03d7b7b54be6ab6983f2c39579ae.
# 2024/09/19 11:56:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:23,505] Trial 35 finished with value: 0.945054945054945 and parameters: {'classifier': 'KNN', 'n_neighbors': 1, 'weights': 'uniform', 'p': 2}. Best is trial 33 with value: 0.989010989010989.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:56:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:56:27 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:27 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/8922c527cb294602949ea9f2f6d76746.
# 2024/09/19 11:56:27 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:27,796] Trial 36 finished with value: 0.9862637362637363 and parameters: {'classifier': 'XGBoost', 'eta': 0.18419253107177405, 'max_depth': 8}. Best is trial 33 with value: 0.989010989010989.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:56:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:56:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:32 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/bed96825de5346c1b70fce0f88a9ea1a.
# 2024/09/19 11:56:32 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:32,217] Trial 37 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.17405292658250288, 'max_depth': 10}. Best is trial 33 with value: 0.989010989010989.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:56:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:56:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/07633f2e7cb64796aa91f81914fa33e7.
# 2024/09/19 11:56:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:36,948] Trial 38 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.19922696984602478, 'max_depth': 8}. Best is trial 33 with value: 0.989010989010989.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:56:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:56:41 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:41 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/5aa8b8e5a20044c99726cf3aa271f531.
# 2024/09/19 11:56:41 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:41,748] Trial 39 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.29316824786059836, 'max_depth': 12}. Best is trial 33 with value: 0.989010989010989.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:56:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:56:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:46 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/b030b90e92e04d258bab09035ae6cd8b.
# 2024/09/19 11:56:46 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:46,150] Trial 40 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.11739510753505, 'max_depth': 11}. Best is trial 33 with value: 0.989010989010989.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 2024/09/19 11:56:50 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:50 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_run at: http://localhost:5000/#/experiments/4/runs/43854b3a94f14cfaa17567d55a59ebb5.
# 2024/09/19 11:56:50 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:50,674] Trial 41 finished with value: 0.9752747252747253 and parameters: {'classifier': 'LogisticRegression', 'C': 9.43022278251988, 'penalty': 'l2'}. Best is trial 33 with value: 0.989010989010989.
# 2024/09/19 11:56:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_run at: http://localhost:5000/#/experiments/4/runs/c767242f1684484c9c976f3fa55cea79.
# 2024/09/19 11:56:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:55,066] Trial 42 finished with value: 0.967032967032967 and parameters: {'classifier': 'SVC', 'C': 6.193363550069734}. Best is trial 33 with value: 0.989010989010989.
# 2024/09/19 11:56:58 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:56:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/4/runs/f65d0c99a38a432fb856c7423a7520e9.
# 2024/09/19 11:56:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:56:59,187] Trial 43 finished with value: 0.9697802197802198 and parameters: {'classifier': 'RandomForest', 'n_estimators': 12, 'max_depth': 14}. Best is trial 33 with value: 0.989010989010989.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:56:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:57:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:57:03 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/36b61fb93f3746c58e3013f8f881d8bb.
# 2024/09/19 11:57:03 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:57:03,552] Trial 44 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.3315995264903, 'max_depth': 7}. Best is trial 33 with value: 0.989010989010989.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:57:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:57:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:57:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/024f0cbae9fd40c1b1071d9e7a473d21.
# 2024/09/19 11:57:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:57:08,271] Trial 45 finished with value: 0.9835164835164835 and parameters: {'classifier': 'XGBoost', 'eta': 0.22211868256302253, 'max_depth': 5}. Best is trial 33 with value: 0.989010989010989.
# 2024/09/19 11:57:12 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:57:12 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_run at: http://localhost:5000/#/experiments/4/runs/4d3b54e73dc246d8a125e2a29acae292.
# 2024/09/19 11:57:12 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:57:12,481] Trial 46 finished with value: 0.9642857142857143 and parameters: {'classifier': 'KNN', 'n_neighbors': 16, 'weights': 'uniform', 'p': 2}. Best is trial 33 with value: 0.989010989010989.
# 2024/09/19 11:57:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:57:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/4/runs/0e11f3d9fda243d6869306c0674d044f.
# 2024/09/19 11:57:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:57:16,773] Trial 47 finished with value: 0.9642857142857143 and parameters: {'classifier': 'RandomForest', 'n_estimators': 139, 'max_depth': 2}. Best is trial 33 with value: 0.989010989010989.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:57:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:57:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:57:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/d2c7b4f229d346cfa0a7743ecd767d7d.
# 2024/09/19 11:57:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:57:21,220] Trial 48 finished with value: 0.9807692307692307 and parameters: {'classifier': 'XGBoost', 'eta': 0.4310376673966779, 'max_depth': 15}. Best is trial 33 with value: 0.989010989010989.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:57:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 11:57:25 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 11:57:26 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_run at: http://localhost:5000/#/experiments/4/runs/d2f0e4516faf4c13a2b61ad03052b022.
# 2024/09/19 11:57:26 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/4.
# [I 2024-09-19 11:57:26,069] Trial 49 finished with value: 0.9752747252747253 and parameters: {'classifier': 'XGBoost', 'eta': 0.13868770283633602, 'max_depth': 8}. Best is trial 33 with value: 0.989010989010989.
# Mejor modelo: {'classifier': 'XGBoost', 'eta': 0.3003621812007603, 'max_depth': 8}
