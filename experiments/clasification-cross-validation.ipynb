# %%
# Para que funciones, todos nuestros scripts debemos exportar las siguientes variables de entorno
# %env AWS_ACCESS_KEY_ID=minio   
# %env AWS_SECRET_ACCESS_KEY=minio123 
# %env MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# %env AWS_ENDPOINT_URL_S3=http://localhost:9000
# Out:
# env: AWS_ACCESS_KEY_ID=minio
# env: AWS_SECRET_ACCESS_KEY=minio123
# env: MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# env: AWS_ENDPOINT_URL_S3=http://localhost:9000

# %%
# !echo $AWS_ACCESS_KEY_ID
# !echo $AWS_SECRET_ACCESS_KEY
# !echo $MLFLOW_S3_ENDPOINT_URL
# Out:
# $AWS_ACCESS_KEY_ID
# $AWS_SECRET_ACCESS_KEY
# $MLFLOW_S3_ENDPOINT_URL

# %%
import awswrangler as wr

# Cargamos los datos para realizar nuestro estudio.
X_train =  wr.s3.read_csv("s3://data/final/train/X_train_scaled.csv")
y_train =  wr.s3.read_csv("s3://data/final/train/y_train.csv")

X_val =  wr.s3.read_csv("s3://data/final/val/X_val_scaled.csv")
y_val =  wr.s3.read_csv("s3://data/final/val/y_val.csv")

X_test =  wr.s3.read_csv("s3://data/final/test/X_test_scaled.csv")
y_test =  wr.s3.read_csv("s3://data/final/test/y_test.csv")

# %%
import pandas as pd
import optuna
import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import KFold


# Set the MLflow tracking URI
mlflow.set_tracking_uri('http://localhost:5000') 

# Set up the MLflow experiment
mlflow.set_experiment("classification-cross-validation-02-02-25_3")

def objective(trial):
    # Elegimos el clasificador aleatoriamente
    classifier_name = trial.suggest_categorical('classifier', 
        ['RandomForest', 'XGBoost', 'SVC', 'LogisticRegression', 'KNN', 'KNN_simple'])
    
    # Combinamos los conjuntos de entrenamiento y validación
    X_combined = pd.concat([X_train, X_val])
    y_combined = pd.concat([y_train, y_val])
    
    # Definimos el número de folds para cross-validation
    n_splits = 5
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    
    if classifier_name == 'RandomForest':
        n_estimators = trial.suggest_int('n_estimators', 10, 100)
        max_depth = trial.suggest_int('max_depth', 2, 32)
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
    
    elif classifier_name == 'XGBoost':
        eta = trial.suggest_float('eta', 0.01, 0.5)
        max_depth = trial.suggest_int('max_depth', 2, 20)
        model = XGBClassifier(eta=eta, max_depth=max_depth, use_label_encoder=False)
    
    elif classifier_name == 'SVC':
        C = trial.suggest_float('C', 0.1, 10.0, log=True)
        model = SVC(C=C)
    
    elif classifier_name == 'LogisticRegression':
        C = trial.suggest_float('C', 0.1, 10.0, log=True)
        penalty = trial.suggest_categorical('penalty', ['l1', 'l2'])
        model = LogisticRegression(C=C, penalty=penalty, solver='liblinear')
    
    elif classifier_name == 'KNN_simple':
        n_neighbors = trial.suggest_int('n_neighbors', 1, 30)
        weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
        p = trial.suggest_int('p', 1, 2)
        model = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights, p=p)
    
    else:  # KNN
        n_neighbors = trial.suggest_int('n_neighbors', 1, 30)
        weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
        p = trial.suggest_int('p', 1, 2)
        model = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights, p=p)
    
    # Lista para almacenar los scores de CV
    cv_scores = []
    cv_f1_scores = []
    
    # Iniciamos una ejecución en MLflow
    with mlflow.start_run(run_name=f"{classifier_name}_cv_run"):
        # Registramos parámetros
        mlflow.log_param("classifier", classifier_name)
        mlflow.log_params(trial.params)
        
        # Realizamos cross-validation
        for fold, (train_idx, val_idx) in enumerate(kf.split(X_combined)):
            X_fold_train = X_combined.iloc[train_idx]
            y_fold_train = y_combined.iloc[train_idx]
            X_fold_val = X_combined.iloc[val_idx]
            y_fold_val = y_combined.iloc[val_idx]
            
            if classifier_name == 'XGBoost':
                model.fit(
                    X_fold_train,
                    y_fold_train,
                    eval_set=[(X_fold_val, y_fold_val)],
                    verbose=False
                )
            else:
                model.fit(X_fold_train, y_fold_train.values.ravel())
            
            # Evaluamos en el fold de validación
            y_pred = model.predict(X_fold_val)
            fold_accuracy = accuracy_score(y_fold_val, y_pred)
            fold_f1 = f1_score(y_fold_val, y_pred, average='weighted')
            
            cv_scores.append(fold_accuracy)
            cv_f1_scores.append(fold_f1)
            # Registramos métricas del fold
            mlflow.log_metric(f"fold_{fold}_accuracy", fold_accuracy)
            mlflow.log_metric(f"fold_{fold}_f1", fold_f1)
        # Calculamos y registramos la media y desviación estándar de CV
        mean_cv_accuracy = np.mean(cv_scores)
        std_cv_accuracy = np.std(cv_scores)
        mean_cv_f1 = np.mean(cv_f1_scores)
        std_cv_f1 = np.std(cv_f1_scores)
        
        mlflow.log_metric("mean_cv_accuracy", mean_cv_accuracy)
        mlflow.log_metric("std_cv_accuracy", std_cv_accuracy)
        mlflow.log_metric("mean_cv_f1", mean_cv_f1)
        mlflow.log_metric("std_cv_f1", std_cv_f1)
        
        # Entrenamos el modelo final con todos los datos combinados
        if classifier_name == 'XGBoost':
            model.fit(
                X_combined,
                y_combined,
                eval_set=[(X_test, y_test)],
                verbose=False
            )
        else:
            model.fit(X_combined, y_combined.values.ravel())
        
        # Evaluamos en el conjunto de prueba
        y_pred = model.predict(X_test)
        test_accuracy = accuracy_score(y_test, y_pred)
        test_f1 = f1_score(y_test, y_pred, average='weighted')
        
        mlflow.log_metric("test_accuracy", test_accuracy)
        mlflow.log_metric("test_f1", test_f1)
        
        # Registramos el modelo final
        mlflow.sklearn.log_model(model, classifier_name)
        
        return mean_cv_f1

# Ejecutamos la optimización con Optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Imprimimos el mejor modelo y sus parámetros
print(f"Mejor modelo: {study.best_trial.params}")
print(f"Mejor accuracy CV: {study.best_trial.value}")
# Out:
# 2025/02/02 00:14:32 INFO mlflow.tracking.fluent: Experiment with name 'classification-cross-validation-02-02-25_3' does not exist. Creating a new experiment.
# [I 2025-02-02 00:14:32,500] A new study created in memory with name: no-name-859ed2a0-79bf-4e76-b2eb-3de2badef31e
# 2025/02/02 00:14:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:14:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_cv_run at: http://localhost:5000/#/experiments/16/runs/9cd81d8a0d18472a9cec9b68a48b5c32.
# 2025/02/02 00:14:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:14:37,167] Trial 0 finished with value: 0.952208601960205 and parameters: {'classifier': 'KNN', 'n_neighbors': 2, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.952208601960205.
# 2025/02/02 00:14:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:14:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_cv_run at: http://localhost:5000/#/experiments/16/runs/aaddf0637404492ebc6adc0f46108655.
# 2025/02/02 00:14:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:14:42,762] Trial 1 finished with value: 0.9440444737818148 and parameters: {'classifier': 'KNN', 'n_neighbors': 10, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.952208601960205.
# 2025/02/02 00:14:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:14:47 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_cv_run at: http://localhost:5000/#/experiments/16/runs/446c462909634a45bcb033e2d7274af8.
# 2025/02/02 00:14:47 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:14:47,267] Trial 2 finished with value: 0.9440444737818148 and parameters: {'classifier': 'KNN', 'n_neighbors': 22, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.952208601960205.
# 2025/02/02 00:14:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:14:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_cv_run at: http://localhost:5000/#/experiments/16/runs/138981d28255440b959cb4b34828b382.
# 2025/02/02 00:14:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:14:52,793] Trial 3 finished with value: 0.9593800031333531 and parameters: {'classifier': 'RandomForest', 'n_estimators': 80, 'max_depth': 31}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:14:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:14:57 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/ca10206defbb4d33b0f26b93cff27232.
# 2025/02/02 00:14:57 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:14:57,307] Trial 4 finished with value: 0.9460198722778254 and parameters: {'classifier': 'LogisticRegression', 'C': 0.10030706241653599, 'penalty': 'l2'}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:15:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:02 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_cv_run at: http://localhost:5000/#/experiments/16/runs/89b9dea1e37245078acfa33a442dd835.
# 2025/02/02 00:15:02 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:02,050] Trial 5 finished with value: 0.9440444737818148 and parameters: {'classifier': 'SVC', 'C': 0.17766581446083923}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:15:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:06 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_cv_run at: http://localhost:5000/#/experiments/16/runs/813465fb9d54481498fe99c2f9ebf59e.
# 2025/02/02 00:15:06 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:06,316] Trial 6 finished with value: 0.9466809377963245 and parameters: {'classifier': 'SVC', 'C': 1.128584727830341}. Best is trial 3 with value: 0.9593800031333531.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2025/02/02 00:15:11 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:11 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_cv_run at: http://localhost:5000/#/experiments/16/runs/9f7e37dd6bae4f2d9e96ac5acc465173.
# 2025/02/02 00:15:11 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:11,963] Trial 7 finished with value: 0.951220826998567 and parameters: {'classifier': 'XGBoost', 'eta': 0.27992561584076564, 'max_depth': 14}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:15:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:17 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_cv_run at: http://localhost:5000/#/experiments/16/runs/293603119e414b13b53f8190410764ba.
# 2025/02/02 00:15:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:17,101] Trial 8 finished with value: 0.9521879676146241 and parameters: {'classifier': 'RandomForest', 'n_estimators': 80, 'max_depth': 3}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:15:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_cv_run at: http://localhost:5000/#/experiments/16/runs/efaee5a324814307b5fcef72cc6a4564.
# 2025/02/02 00:15:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:21,168] Trial 9 finished with value: 0.9482307870588305 and parameters: {'classifier': 'SVC', 'C': 1.334084260482923}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:15:26 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:26 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_cv_run at: http://localhost:5000/#/experiments/16/runs/684582245cb8477b9c1ffe4c8ae69d3a.
# 2025/02/02 00:15:26 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:26,520] Trial 10 finished with value: 0.9579880308346309 and parameters: {'classifier': 'RandomForest', 'n_estimators': 73, 'max_depth': 28}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:15:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:32 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_cv_run at: http://localhost:5000/#/experiments/16/runs/c98febece8fa447abf7e0c6007b7a114.
# 2025/02/02 00:15:32 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:32,071] Trial 11 finished with value: 0.9577268777125909 and parameters: {'classifier': 'RandomForest', 'n_estimators': 79, 'max_depth': 32}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:15:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_cv_run at: http://localhost:5000/#/experiments/16/runs/cab8b7a657c34de7966e2e51d5829d0f.
# 2025/02/02 00:15:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:36,648] Trial 12 finished with value: 0.9530664093772183 and parameters: {'classifier': 'RandomForest', 'n_estimators': 41, 'max_depth': 32}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:15:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_simple_cv_run at: http://localhost:5000/#/experiments/16/runs/d2dd4420b6644c15b669628d5198d1fb.
# 2025/02/02 00:15:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:40,672] Trial 13 finished with value: 0.9436829453046516 and parameters: {'classifier': 'KNN_simple', 'n_neighbors': 30, 'weights': 'distance', 'p': 1}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:15:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_cv_run at: http://localhost:5000/#/experiments/16/runs/c5f17af71aaa4c3a8f6c41dedd9fa11b.
# 2025/02/02 00:15:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:45,425] Trial 14 finished with value: 0.9591111623857682 and parameters: {'classifier': 'RandomForest', 'n_estimators': 94, 'max_depth': 23}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:15:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:50 INFO mlflow.tracking._tracking_service.client: 🏃 View run RandomForest_cv_run at: http://localhost:5000/#/experiments/16/runs/d36b1c42f1b6470a906d9c8508c7dac1.
# 2025/02/02 00:15:50 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:50,119] Trial 15 finished with value: 0.9567707225230819 and parameters: {'classifier': 'RandomForest', 'n_estimators': 97, 'max_depth': 22}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:15:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:54 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_simple_cv_run at: http://localhost:5000/#/experiments/16/runs/936b1c1ba6184ff8b2b50af2d0023e28.
# 2025/02/02 00:15:54 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:54,470] Trial 16 finished with value: 0.946661555654174 and parameters: {'classifier': 'KNN_simple', 'n_neighbors': 15, 'weights': 'distance', 'p': 1}. Best is trial 3 with value: 0.9593800031333531.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:15:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2025/02/02 00:15:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:15:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_cv_run at: http://localhost:5000/#/experiments/16/runs/ffba9e82b4ad4a748072d1289f686e74.
# 2025/02/02 00:15:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:15:59,702] Trial 17 finished with value: 0.950403444033929 and parameters: {'classifier': 'XGBoost', 'eta': 0.01875004196201227, 'max_depth': 15}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:16:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:03 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/ef9af985b9694284b4a84956c408f402.
# 2025/02/02 00:16:03 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:03,491] Trial 18 finished with value: 0.9592273989199598 and parameters: {'classifier': 'LogisticRegression', 'C': 6.3683798628123585, 'penalty': 'l1'}. Best is trial 3 with value: 0.9593800031333531.
# 2025/02/02 00:16:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:06 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/7dd36b718c6c40e4b2c1836931f0d382.
# 2025/02/02 00:16:06 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:07,008] Trial 19 finished with value: 0.9602066816079716 and parameters: {'classifier': 'LogisticRegression', 'C': 9.490791980882449, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:10 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:10 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/2cf6f74c9fca4336a02c15a4b5a20dbf.
# 2025/02/02 00:16:10 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:10,664] Trial 20 finished with value: 0.9592273989199598 and parameters: {'classifier': 'LogisticRegression', 'C': 5.308173583666526, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:14 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/2e9c30fdd06e496a84f4d78f7edca12e.
# 2025/02/02 00:16:14 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:14,722] Trial 21 finished with value: 0.9602066816079716 and parameters: {'classifier': 'LogisticRegression', 'C': 9.073087759881052, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/fdba8e7e7612444f8d68e6fb5410d0a2.
# 2025/02/02 00:16:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:18,481] Trial 22 finished with value: 0.9602066816079716 and parameters: {'classifier': 'LogisticRegression', 'C': 8.513135671510017, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:22 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/882713601c0a4900be1a54320e0de973.
# 2025/02/02 00:16:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:22,418] Trial 23 finished with value: 0.9602066816079716 and parameters: {'classifier': 'LogisticRegression', 'C': 9.678012762100193, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:26 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:27 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/b16ba8efe7ae4ca09a9e4c3602a26027.
# 2025/02/02 00:16:27 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:27,045] Trial 24 finished with value: 0.9592273989199598 and parameters: {'classifier': 'LogisticRegression', 'C': 3.380690124740662, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:30 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/163388219db249deb52e5777d0c8c98e.
# 2025/02/02 00:16:30 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:30,920] Trial 25 finished with value: 0.9592273989199598 and parameters: {'classifier': 'LogisticRegression', 'C': 3.7174430051304204, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/6a9d37d4225f406f83185099bb0c4123.
# 2025/02/02 00:16:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:35,014] Trial 26 finished with value: 0.9602066816079716 and parameters: {'classifier': 'LogisticRegression', 'C': 9.957611668539366, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:39 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/7b52be8143714f37b56a4411286ecf1f.
# 2025/02/02 00:16:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:39,187] Trial 27 finished with value: 0.9585506371258014 and parameters: {'classifier': 'LogisticRegression', 'C': 2.5505079664261543, 'penalty': 'l2'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:43 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:43 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/92c7718736874bd1b0a246ec2827b52a.
# 2025/02/02 00:16:43 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:43,530] Trial 28 finished with value: 0.9602066816079716 and parameters: {'classifier': 'LogisticRegression', 'C': 9.726676576130332, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/a9d90ec50be74cb289e4fc22aa343df7.
# 2025/02/02 00:16:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:48,291] Trial 29 finished with value: 0.9585638804564299 and parameters: {'classifier': 'LogisticRegression', 'C': 0.5992039333802888, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/110ee7cf0d2b45738c3396f320a519d6.
# 2025/02/02 00:16:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:52,641] Trial 30 finished with value: 0.9585506371258014 and parameters: {'classifier': 'LogisticRegression', 'C': 2.0742225008423163, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:16:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:16:58 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/4238f6c596fb4c50ab26241a58efd451.
# 2025/02/02 00:16:58 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:16:58,124] Trial 31 finished with value: 0.9602066816079716 and parameters: {'classifier': 'LogisticRegression', 'C': 7.1849899368320695, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:02 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:02 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_cv_run at: http://localhost:5000/#/experiments/16/runs/e686b778d8d84f62bc4bea62ea917f33.
# 2025/02/02 00:17:02 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:02,411] Trial 32 finished with value: 0.9538050072145815 and parameters: {'classifier': 'KNN', 'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:07 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/521aa71070cc43f89572ff5bf38c12f3.
# 2025/02/02 00:17:07 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:07,093] Trial 33 finished with value: 0.9592273989199598 and parameters: {'classifier': 'LogisticRegression', 'C': 5.24193880792121, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:11 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:11 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_cv_run at: http://localhost:5000/#/experiments/16/runs/734dbf76b567467a882b518d5808ce06.
# 2025/02/02 00:17:11 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:11,303] Trial 34 finished with value: 0.9440444737818148 and parameters: {'classifier': 'KNN', 'n_neighbors': 30, 'weights': 'uniform', 'p': 1}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/c420d8e3a3c548b880a961b26a5381e5.
# 2025/02/02 00:17:15 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:15,177] Trial 35 finished with value: 0.9602066816079716 and parameters: {'classifier': 'LogisticRegression', 'C': 8.960202619251056, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:19 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_simple_cv_run at: http://localhost:5000/#/experiments/16/runs/bf8f38ff1cf1428e980ff75a28e4ef31.
# 2025/02/02 00:17:19 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:19,112] Trial 36 finished with value: 0.9440444737818148 and parameters: {'classifier': 'KNN_simple', 'n_neighbors': 22, 'weights': 'distance', 'p': 2}. Best is trial 19 with value: 0.9602066816079716.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:17:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:17:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:17:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:17:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:17:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:17:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2025/02/02 00:17:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_cv_run at: http://localhost:5000/#/experiments/16/runs/f7dbd45faab043098acf48c2091d3d5f.
# 2025/02/02 00:17:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:23,996] Trial 37 finished with value: 0.9520911753142471 and parameters: {'classifier': 'XGBoost', 'eta': 0.49625145765713485, 'max_depth': 2}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:27 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:27 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/7194f7daf44c42ab86a74ee9666a9029.
# 2025/02/02 00:17:27 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:27,667] Trial 38 finished with value: 0.9592273989199598 and parameters: {'classifier': 'LogisticRegression', 'C': 5.075049166126838, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/247e3ab7779a433bb10d2b6aafb9f371.
# 2025/02/02 00:17:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:31,550] Trial 39 finished with value: 0.9535444822008514 and parameters: {'classifier': 'LogisticRegression', 'C': 0.5700462992340651, 'penalty': 'l2'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_cv_run at: http://localhost:5000/#/experiments/16/runs/b8b74f910e034c85874f76388a9ad461.
# 2025/02/02 00:17:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:36,335] Trial 40 finished with value: 0.9507393219280681 and parameters: {'classifier': 'SVC', 'C': 9.85232778967449}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/bfaf02bb27994b28960c90bf7fcb445b.
# 2025/02/02 00:17:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:40,660] Trial 41 finished with value: 0.9602066816079716 and parameters: {'classifier': 'LogisticRegression', 'C': 9.722656374661955, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/e150e6d5aaef4ec6ab60b44151d81c23.
# 2025/02/02 00:17:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:45,336] Trial 42 finished with value: 0.9602066816079716 and parameters: {'classifier': 'LogisticRegression', 'C': 6.897256862986105, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/58b593e678d34554ae542d2cd5aaa7fb.
# 2025/02/02 00:17:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:49,970] Trial 43 finished with value: 0.9592273989199598 and parameters: {'classifier': 'LogisticRegression', 'C': 4.177968189847744, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/28c4fe60e5374fe0949ab7daa652dd83.
# 2025/02/02 00:17:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:55,140] Trial 44 finished with value: 0.9592273989199598 and parameters: {'classifier': 'LogisticRegression', 'C': 6.43668640949589, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:17:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:17:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_cv_run at: http://localhost:5000/#/experiments/16/runs/7359de9b6d074412b22c2bf36ba2b530.
# 2025/02/02 00:17:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:17:59,670] Trial 45 finished with value: 0.9433213325115946 and parameters: {'classifier': 'KNN', 'n_neighbors': 9, 'weights': 'uniform', 'p': 2}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:18:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:18:04 INFO mlflow.tracking._tracking_service.client: 🏃 View run SVC_cv_run at: http://localhost:5000/#/experiments/16/runs/14d0c75ae8274f8d97490c3bdc48f2b6.
# 2025/02/02 00:18:04 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:18:04,300] Trial 46 finished with value: 0.9517413685882923 and parameters: {'classifier': 'SVC', 'C': 7.464000139312073}. Best is trial 19 with value: 0.9602066816079716.
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:18:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:18:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:18:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:18:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:18:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\andre\workspace\andresmalvestiti-UBA-trabajo-final-experiments\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:18:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 2025/02/02 00:18:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:18:09 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_cv_run at: http://localhost:5000/#/experiments/16/runs/d231557ded3b4c7d8643d12c5f015cf5.
# 2025/02/02 00:18:09 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:18:09,451] Trial 47 finished with value: 0.950403444033929 and parameters: {'classifier': 'XGBoost', 'eta': 0.020047872586019228, 'max_depth': 6}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:18:13 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:18:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run LogisticRegression_cv_run at: http://localhost:5000/#/experiments/16/runs/666922218220405eb77367e23fac83bb.
# 2025/02/02 00:18:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:18:13,770] Trial 48 finished with value: 0.9602066816079716 and parameters: {'classifier': 'LogisticRegression', 'C': 7.022881285346143, 'penalty': 'l1'}. Best is trial 19 with value: 0.9602066816079716.
# 2025/02/02 00:18:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/02 00:18:17 INFO mlflow.tracking._tracking_service.client: 🏃 View run KNN_simple_cv_run at: http://localhost:5000/#/experiments/16/runs/a360c519976e4a7691f2a2e6c2408f95.
# 2025/02/02 00:18:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/16.
# [I 2025-02-02 00:18:17,961] Trial 49 finished with value: 0.947023168447231 and parameters: {'classifier': 'KNN_simple', 'n_neighbors': 22, 'weights': 'distance', 'p': 1}. Best is trial 19 with value: 0.9602066816079716.
# Mejor modelo: {'classifier': 'LogisticRegression', 'C': 9.490791980882449, 'penalty': 'l1'}
# Mejor accuracy CV: 0.9602066816079716
